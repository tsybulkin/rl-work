# %% [markdown]
# # RL Workshop
# Ian Tsybulkin
#
# May 2019

# %% [markdown]
# ## 0. Plan
#
# - Preparing your working environment
# - Introduction
# - RL model
# - Gym: Ready to go Environments from Open AI
# - Developing RL-Agent
# - Temporal Learning, Q-learning
# -
# -
#
# ## 1. Preparation
# ### Libraries
# We will need some generic libraries:
# - Numpy
# - matplotlib
#
# and a librirary that contains many different enironments (worlds) from Open AI:
# - gym ( https://gym.openai.com/docs/#environments )

# %% [markdown]
# ## 2. RL Model
# ![Model](imgs/model.png "Model")

# %% [markdown]
# Let us create some of the Open AI's environments.
#
# ###  Environment: CartPole

# %%
import matplotlib.pyplot as plt
import gym

env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
env.reset()
env.render()
# Out:
# True

# %%
env.close()

# %%
env.reset()
# Out:
# array([ 0.02605075, -0.04498495,  0.04511996,  0.02224832])

# %% [markdown]
# This is a state of the environment after its initialization.

# %%
print("Rewards:", env.reward_range)
print("Action space:",env.action_space)
print("State space:",env.observation_space)
# Out:
# Rewards: (-inf, inf)
# Action space: Discrete(2)
# State space: Box(4,)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.step(0)
# Out:
# (array([ 0.02515105, -0.24072395,  0.04556493,  0.32881877]), 1.0, False, {})

# %% [markdown]
# The main loop:
#
# (state, reward, is_terminal, info) = **env.step** (action)
#
#
# Let us create a simple episode:

# %%
is_terminal = False

while not is_terminal:
    action = env.action_space.sample()
    state, reward, is_terminal, _ = env.step(action)
    print(state, reward)
# Out:
# [ 0.02033657 -0.04627927  0.0521413   0.05084593] 1.0
# [ 0.01941099  0.14805776  0.05315822 -0.22494084] 1.0
# [ 0.02237214 -0.04778205  0.0486594   0.08402507] 1.0
# [ 0.0214165   0.14660984  0.0503399  -0.19291741] 1.0
# [ 0.0243487   0.34097688  0.04648156 -0.46930496] 1.0
# [ 0.03116824  0.53541245  0.03709546 -0.74698264] 1.0
# [ 0.04187648  0.73000349  0.0221558  -1.02776484] 1.0
# [ 0.05647655  0.92482363  0.00160051 -1.31341005] 1.0
# [ 0.07497303  1.11992529 -0.02466769 -1.60559161] 1.0
# [ 0.09737153  1.31533013 -0.05677953 -1.90586128] 1.0
# [ 0.12367813  1.12086546 -0.09489675 -1.63131855] 1.0
# [ 0.14609544  0.92697767 -0.12752312 -1.36965321] 1.0
# [ 0.164635    1.12344346 -0.15491619 -1.69934918] 1.0
# [ 0.18710387  0.93040941 -0.18890317 -1.45862905] 1.0
# [ 0.20571205  0.73803918 -0.21807575 -1.23041469] 1.0

# %% [markdown]
# ###  Environment: MountainCarContinous

# %%
env = gym.make('MountainCar-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
env.action_space
# Out:
# Discrete(3)

# %%
env.observation_space
# Out:
# Box(2,)

# %% [markdown]
# And now let us simulate 5 episodes and look at what we will get.

# %%
episodes = []
for _ in range(5):
    states = []
    states.append(env.reset())
    
    done = False
    i = 0
    while not done and i < 50:
        i += 1
        action = env.action_space.sample()
        state,_,done,_ = env.step(action)
        states.append(state)
    episodes.append(states[:])
    
env.close()

# %%
for states in episodes:
    x,y = zip(*states)
    plt.plot(x,y,'--')
    
plt.show()

# %% [markdown]
# ## Agent

# %%
env = gym.make('MountainCar-v0')
env.action_space
import time
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
done = False
env.reset()
for _ in range(100):
    env.render()
    time.sleep(0.05)
    env.step(0)

env.close()

# %% [markdown]
# let us create an agent

# %%
env = gym.make('MountainCar-v0')
_,v = env.reset()

done = False
i = 0
while not done and i < 1000:
    env.render()
    i += 1
    time.sleep(0.1)
    if v > 0:
        action = 2
    else:
        action = 0
    (_,v),_,done,_ = env.step(action)

env.close()
print(i)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# 156
